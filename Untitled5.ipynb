# %%
#Importa a biblioteca Pandas
import pandas as pd
#Leitura do arquivo CSV de imóveis do RJ
pd.read_csv('ANALISE.csv')
# Out:
#    MESES;RECLAMACAO;;;;;;;;
# 0        JANEIRO;11;;;;;;;;
# 1      FEVEREIRO;11;;;;;;;;
# 2           MARCO;5;;;;;;;;
# 3           ABRIL;9;;;;;;;;
# 4            MAIO;4;;;;;;;;
# 5           JUNHO;3;;;;;;;;
# 6          JULHO;14;;;;;;;;
# 7         AGOSTO;15;;;;;;;;
# 8        SETEMBRO;2;;;;;;;;
# 9         OUTUBRO;2;;;;;;;;
# 10       NOVEMBRO;4;;;;;;;;
# 11       DEZEMBRO;2;;;;;;;;

# %%
dados = pd.read_csv('ANALISE.csv', sep=';')
dados
# Out:
#         MESES  RECLAMACAO  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0     JANEIRO          11         NaN         NaN         NaN         NaN
# 1   FEVEREIRO          11         NaN         NaN         NaN         NaN
# 2       MARCO           5         NaN         NaN         NaN         NaN
# 3       ABRIL           9         NaN         NaN         NaN         NaN
# 4        MAIO           4         NaN         NaN         NaN         NaN
# 5       JUNHO           3         NaN         NaN         NaN         NaN
# 6       JULHO          14         NaN         NaN         NaN         NaN
# 7      AGOSTO          15         NaN         NaN         NaN         NaN
# 8    SETEMBRO           2         NaN         NaN         NaN         NaN
# 9     OUTUBRO           2         NaN         NaN         NaN         NaN
# 10   NOVEMBRO           4         NaN         NaN         NaN         NaN
# 11   DEZEMBRO           2         NaN         NaN         NaN         NaN
#
# ...

# %%
#Importar a biblioteca

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
reclamacoes =dados.groupby('MESES')["RECLAMACAO"].mean()

MESES = ['JANEIRO','FEVEREIRO','MARÇO','ABRIL','MAIO','JUNHO','JULHO','AGOSTO','SETEMBRO','OUTUBRO','NOVEMBRO','DEZEMBRO']



#Cria as dimensões da figura do gráfico
fig, ax = plt.subplots(figsize = (17,17))
#Cor para o gráfico
cor  = ("#CC00FF", "#DF5DFF", "#EEBAFA", "#FFFFFF", "#BDEEF9","#97FFDC","#8BFFD8", "#75F1C8", "#6BFFCE",
"#51FFC5")

ax.bar(MESES,reclamacoes,width=0.6,color=cor,edgecolor="black")
ax.set_title("Reclamações por mes", fontsize=20)
ax.set_ylabel("Reclamações", fontsize=19)
ax.set_xlabel("Meses", fontsize=19)

for MESES, media in enumerate(reclamacoes):
  plt.text(x=MESES-.20,y=media+0.1,s=media,fontdict=dict(fontsize=20))
plt.tight_layout()
plt.show()
